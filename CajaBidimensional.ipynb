# %%
#Importamos las bibliotecas a utilizar
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# $$ \psi(x,y)= \sqrt{ \frac{4}{ab}} sin( \frac{n\pi x}{a}) sin( \frac{m\pi y}{b})$$

# %%
#Definimos nuestra función
def f(x, y, n, m, a, b):
    return np.sin(n*x*np.pi/a)*np.sin(m*y*np.pi/b)*np.sqrt(4/(a*b))

# %%
#Definimos el valor de nuestros parámetros
n=2
m=1
a=1
b=1

#Establecemos el rango de nuestro eje
x = np.linspace(0, 1, 50)
y = np.linspace(0, 1, 50)

#Generamos los valores de nuestra cuadrícula 
X, Y = np.meshgrid(x, y)

#Calculamos los valores de la función 
Z = f(X, Y, n, m, a, b)

#Gráficamos:

#Tamaño de la figura
fig=plt.figure(figsize=(12,8))

#Graficamos una superficie 
ax = fig.gca(projection='3d')
graf=ax.plot_surface(X, Y, Z, cmap="coolwarm")
fig.colorbar(graf, shrink=0.5, aspect=5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel("\u03C8")

plt.show()

# %%
#Vista superior de la figura

#Tamaño de la figura
fig=plt.figure(figsize=(12,8))

#Graficamos una superficie 
ax = fig.gca(projection='3d')
graf=ax.plot_surface(X, Y, Z, cmap="coolwarm")
fig.colorbar(graf, shrink=0.5, aspect=5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel("\u03C8")

ax.view_init(elev=90., azim=-90)

plt.show()
